# %%
import numpy as np
import nibabel as nib
import os
from glob import glob
import matplotlib.pyplot as plt

# %%
main_directory = "archive/BraTS2021_Training_Data/test"

# %%
main_directory = "archive/BraTS2021_Training_Data/test/BraTS2021_01559"

# Get a list of all MRI files in the dataset folder
mri_files = glob(os.path.join(main_directory, "*.nii.gz"))

# Iterate over each MRI file and load its data array
mri_shapes = []
for file in mri_files:
    # Load the MRI data
    mri_data = nib.load(file).get_fdata()
    # Get the shape of the MRI data array
    mri_shape = mri_data.shape
    # Append the shape to the list
    mri_shapes.append(mri_shape)

# Print the sizes of the loaded MRIs
for i, shape in enumerate(mri_shapes):
    print(f"MRI {i+1}: Shape {shape}")
# Out:
# MRI 1: Shape (240, 240, 155)
# MRI 2: Shape (240, 240, 155)
# MRI 3: Shape (240, 240, 155)
# MRI 4: Shape (240, 240, 155)
# MRI 5: Shape (240, 240, 155)

# %%
import numpy as np
import os
from glob import glob
import nibabel as nib

import numpy as np
import os
from glob import glob
import nibabel as nib

main_directory = "archive/BraTS2021_Training_Data/test"

# Get a list of all MRI files in the dataset folder
mri_files = glob(os.path.join(main_directory, "*.nii.gz"))

# Define the target size
target_size = (256, 256, 256)

# Initialize a list to store resized MRI data
resized_mri_data = []

# Iterate over each MRI file, load its data, and resize it
for file in mri_files:
    # Load the MRI data
    mri_data = nib.load(file).get_fdata()
    
    # Get the shape of the original MRI data
    original_size = mri_data.shape
    
    # Create an array of zeros with the target size
    padded_mri_data = np.zeros(target_size)
    
    # Calculate the starting indices to copy the original MRI data into the padded array
    start_indices = tuple((np.array(target_size) - np.array(original_size)) // 2)
    
    # Calculate the ending indices to copy the original MRI data into the padded array
    end_indices = tuple(start_indices + np.array(original_size))
    
    # Copy the original MRI data into the center of the padded array
    padded_mri_data[start_indices[0]:end_indices[0], 
                    start_indices[1]:end_indices[1], 
                    start_indices[2]:end_indices[2]] = mri_data
    
    # Append the padded MRI data to the list
    resized_mri_data.append(padded_mri_data)

# Convert the padded MRIs to a numpy array and print their shapes
resized_mri_data = np.array(resized_mri_data)
print("Resized MRIs shape:", resized_mri_data.shape)


# Get a list of all MRI files in the dataset folder
mri_files = glob(os.path.join(main_directory, "*.nii.gz"))

# Define the target size
target_size = (256, 256, 256)

# Initialize a list to store resized MRI data
resized_mri_data = []

# Iterate over each MRI file, load its data, and resize it
for file in mri_files:
    # Load the MRI data
    mri_data = nib.load(file).get_fdata()
    
    # Get the shape of the original MRI data
    original_size = mri_data.shape
    
    # Create an array of zeros with the target size
    padded_mri_data = np.zeros(target_size)
    
    # Calculate the starting indices to copy the original MRI data into the padded array
    start_indices = tuple((np.array(target_size) - np.array(original_size)) // 2)
    
    # Calculate the ending indices to copy the original MRI data into the padded array
    end_indices = tuple(start_indices + np.array(original_size))
    
    # Copy the original MRI data into the center of the padded array
    padded_mri_data[start_indices[0]:end_indices[0], 
                    start_indices[1]:end_indices[1], 
                    start_indices[2]:end_indices[2]] = mri_data
    
    # Append the padded MRI data to the list
    resized_mri_data.append(padded_mri_data)

# Convert the padded MRIs to a numpy array and print their shapes
resized_mri_data = np.array(resized_mri_data)
print("Resized MRIs shape:", resized_mri_data.shape)
import numpy as np
import os
from glob import glob
import nibabel as nib

main_directory = "archive/BraTS2021_Training_Data/test"

# Get a list of all MRI files in the dataset folder
mri_files = glob(os.path.join(main_directory, "*.nii.gz"))

# Define the target size
target_size = (256, 256, 256)

# Initialize a list to store resized MRI data
resized_mri_data = []

# Iterate over each MRI file, load its data, and resize it
for file in mri_files:
    # Load the MRI data
    mri_data = nib.load(file).get_fdata()
    
    # Get the shape of the original MRI data
    original_size = mri_data.shape
    
    # Create an array of zeros with the target size
    padded_mri_data = np.zeros(target_size)
    
    # Calculate the starting indices to copy the original MRI data into the padded array
    start_indices = tuple((np.array(target_size) - np.array(original_size)) // 2)
    
    # Calculate the ending indices to copy the original MRI data into the padded array
    end_indices = tuple(start_indices + np.array(original_size))
    
    # Copy the original MRI data into the center of the padded array
    padded_mri_data[start_indices[0]:end_indices[0], 
                    start_indices[1]:end_indices[1], 
                    start_indices[2]:end_indices[2]] = mri_data
    
    # Append the padded MRI data to the list
    resized_mri_data.append(padded_mri_data)

# Convert the padded MRIs to a numpy array and print their shapes
resized_mri_data = np.array(resized_mri_data)
print("Resized MRIs shape:", resized_mri_data.shape)
# Out:
# Resized MRIs shape: (0,)
# Resized MRIs shape: (0,)
# Resized MRIs shape: (0,)

# %%
main_directory = "archive/BraTS2021_Training_Data/test/BraTS2021_01559"

# Get a list of all MRI files in the dataset folder
mri_files = glob(os.path.join(main_directory, "*.nii.gz"))

# Define the target size
target_size = (256, 256, 256)

# Initialize a list to store resized MRI data
resized_mri_data = []

# Iterate over each MRI file, load its data, and resize it
for file in mri_files:
    # Load the MRI data
    mri_data = nib.load(file).get_fdata()
    
    # Get the shape of the original MRI data
    original_size = mri_data.shape
    
    # Create an array of zeros with the target size
    padded_mri_data = np.zeros(target_size)
    
    # Calculate the starting indices to copy the original MRI data into the padded array
    start_indices = tuple((np.array(target_size) - np.array(original_size)) // 2)
    
    # Calculate the ending indices to copy the original MRI data into the padded array
    end_indices = tuple(start_indices + np.array(original_size))
    
    # Copy the original MRI data into the center of the padded array
    padded_mri_data[start_indices[0]:end_indices[0], 
                    start_indices[1]:end_indices[1], 
                    start_indices[2]:end_indices[2]] = mri_data
    
    # Append the padded MRI data to the list
    resized_mri_data.append(padded_mri_data)

# Convert the padded MRIs to a numpy array and print their shapes
resized_mri_data = np.array(resized_mri_data)
print("Resized MRIs shape:", resized_mri_data.shape)


# Get a list of all MRI files in the dataset folder
mri_files = glob(os.path.join(main_directory, "*.nii.gz"))

# Define the target size
target_size = (256, 256, 256)

# Initialize a list to store resized MRI data
resized_mri_data = []

# Iterate over each MRI file, load its data, and resize it
for file in mri_files:
    # Load the MRI data
    mri_data = nib.load(file).get_fdata()
    
    # Get the shape of the original MRI data
    original_size = mri_data.shape
    
    # Create an array of zeros with the target size
    padded_mri_data = np.zeros(target_size)
    
    # Calculate the starting indices to copy the original MRI data into the padded array
    start_indices = tuple((np.array(target_size) - np.array(original_size)) // 2)
    
    # Calculate the ending indices to copy the original MRI data into the padded array
    end_indices = tuple(start_indices + np.array(original_size))
    
    # Copy the original MRI data into the center of the padded array
    padded_mri_data[start_indices[0]:end_indices[0], 
                    start_indices[1]:end_indices[1], 
                    start_indices[2]:end_indices[2]] = mri_data
    
    # Append the padded MRI data to the list
    resized_mri_data.append(padded_mri_data)

# Convert the padded MRIs to a numpy array and print their shapes
resized_mri_data = np.array(resized_mri_data)
print("Resized MRIs shape:", resized_mri_data.shape)
# Out:
# Resized MRIs shape: (5, 256, 256, 256)
# Resized MRIs shape: (5, 256, 256, 256)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming `volumes` is a list of 3D numpy arrays, each representing an MRI volume
volumes = [np.random.rand(64, 64, 64) for _ in range(4)]  # Example data

def plot_volume_slices(volume, num_slices=16):
    fig, axes = plt.subplots(1, num_slices, figsize=(20, 2))
    slice_interval = volume.shape[2] // num_slices
    
    for i in range(num_slices):
        ax = axes[i]
        slice_index = i * slice_interval
        ax.imshow(volume[:, :, slice_index], cmap='gray')
        ax.axis('off')
        
    plt.tight_layout()
    plt.show()

# Visualize each MRI volume with a reasonable number of slices
for i, volume in enumerate(volumes):
    print(f"Visualization of MRI volume {i+1}:")
    plot_volume_slices(volume)
# Out:
# Visualization of MRI volume 1:
# Visualization of MRI volume 2:
# Visualization of MRI volume 3:
# Visualization of MRI volume 4:

# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load the MRI volumes
mri_volume1 = nib.load('archive/BraTS2021_Training_Data/test/BraTS2021_01559/BraTS2021_01559_flair.nii.gz').get_fdata()
mri_volume2 = nib.load('archive/BraTS2021_Training_Data/test/BraTS2021_01559/BraTS2021_01559_t1.nii.gz').get_fdata()
mri_volume3 = nib.load('archive/BraTS2021_Training_Data/test/BraTS2021_01559/BraTS2021_01559_t1ce.nii.gz').get_fdata()
mri_volume4 = nib.load('archive/BraTS2021_Training_Data/test/BraTS2021_01559/BraTS2021_01559_t2.nii.gz').get_fdata()

# Define a function to plot a single slice
def plot_slice(volume, slice_index, title):
    plt.figure()
    plt.imshow(volume[:, :, slice_index], cmap='gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

# Calculate the middle slice index for each volume
middle_slice_index1 = mri_volume1.shape[2] // 2
middle_slice_index2 = mri_volume2.shape[2] // 2
middle_slice_index3 = mri_volume3.shape[2] // 2
middle_slice_index4 = mri_volume4.shape[2] // 2

# Plot the middle slice of each volume
plot_slice(mri_volume1, middle_slice_index1, 'Volume 1 - Middle Slice')
plot_slice(mri_volume2, middle_slice_index2, 'Volume 2 - Middle Slice')
plot_slice(mri_volume3, middle_slice_index3, 'Volume 3 - Middle Slice')
plot_slice(mri_volume4, middle_slice_index4, 'Volume 4 - Middle Slice')

# %%
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from glob import glob
import os

main_directory = "archive/BraTS2021_Training_Data/test/BraTS2021_01559"

# Get a list of all MRI files in the dataset folder
mri_files = glob(os.path.join(main_directory, "*.nii.gz"))

# Define the target size
target_size = (256, 256, 256)

# Initialize a list to store resized MRI data
resized_mri_data = []

# Iterate over each MRI file, load its data, and resize it
for file in mri_files:
    # Load the MRI data
    mri_data = nib.load(file).get_fdata()
    
    # Get the shape of the original MRI data
    original_size = mri_data.shape
    
    # Create an array of zeros with the target size
    padded_mri_data = np.zeros(target_size)
    
    # Calculate the starting indices to copy the original MRI data into the padded array
    start_indices = tuple((np.array(target_size) - np.array(original_size)) // 2)
    
    # Calculate the ending indices to copy the original MRI data into the padded array
    end_indices = tuple(start_indices + np.array(original_size))
    
    # Copy the original MRI data into the center of the padded array
    padded_mri_data[start_indices[0]:end_indices[0], 
                    start_indices[1]:end_indices[1], 
                    start_indices[2]:end_indices[2]] = mri_data
    
    # Append the padded MRI data to the list
    resized_mri_data.append(padded_mri_data)

# Convert the padded MRIs to a numpy array and print their shapes
resized_mri_data = np.array(resized_mri_data)
print("Resized MRIs shape:", resized_mri_data.shape)

# Define a function to plot a single slice
def plot_slice(volume, slice_index, title):
    plt.figure()
    plt.imshow(volume[:,slice_index, :], cmap='gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

# Calculate the middle slice index for each volume
middle_slice_index = target_size[2] // 2

# Plot the middle slice of each resized volume
for i, volume in enumerate(resized_mri_data):
    plot_slice(volume, middle_slice_index, f'Volume {i+1} - Middle Slice')
# Out:
# Resized MRIs shape: (5, 256, 256, 256)

# %%
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
from glob import glob
import os

main_directory = "archive/BraTS2021_Training_Data/test/BraTS2021_01559"

# Get a list of all MRI files in the dataset folder
mri_files = glob(os.path.join(main_directory, "*.nii.gz"))

# Define the target size
target_size = (256, 256, 256)

# Initialize lists to store original and resized MRI data
original_mri_data = []
resized_mri_data = []

# Iterate over each MRI file, load its data, and resize it
for file in mri_files:
    # Load the MRI data
    mri_data = nib.load(file).get_fdata()
    
    # Append the original MRI data to the list
    original_mri_data.append(mri_data)
    
    # Get the shape of the original MRI data
    original_size = mri_data.shape
    
    # Create an array of zeros with the target size
    padded_mri_data = np.zeros(target_size)
    
    # Calculate the starting indices to copy the original MRI data into the padded array
    start_indices = tuple((np.array(target_size) - np.array(original_size)) // 2)
    
    # Calculate the ending indices to copy the original MRI data into the padded array
    end_indices = tuple(start_indices + np.array(original_size))
    
    # Copy the original MRI data into the center of the padded array
    padded_mri_data[start_indices[0]:end_indices[0], 
                    start_indices[1]:end_indices[1], 
                    start_indices[2]:end_indices[2]] = mri_data
    
    # Append the padded MRI data to the list
    resized_mri_data.append(padded_mri_data)

# Convert the original and padded MRIs to numpy arrays
original_mri_data = np.array(original_mri_data)
resized_mri_data = np.array(resized_mri_data)

print("Original MRIs shape:", [data.shape for data in original_mri_data])
print("Resized MRIs shape:", resized_mri_data.shape)

# Define a function to plot a single slice
def plot_slices(original_volume, resized_volume, slice_index, title):
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    
    axes[0].imshow(original_volume[slice_index,:, :], cmap='gray')
    axes[0].set_title('Original ' + title)
    axes[0].axis('off')
    
    axes[1].imshow(resized_volume[:, slice_index, :], cmap='gray')
    axes[1].set_title('Resized ' + title)
    axes[1].axis('off')
    
    plt.show()

# Calculate the middle slice index for the second axis
middle_slice_index = target_size[1] // 2

# Plot the middle slice of each original and resized volume
for i, (original_volume, resized_volume) in enumerate(zip(original_mri_data, resized_mri_data)):
    plot_slices(original_volume, resized_volume, middle_slice_index, f'Volume {i+1} - Middle Slice')
# Out:
# Original MRIs shape: [(240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155), (240, 240, 155)]
# Resized MRIs shape: (5, 256, 256, 256)

# %%
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import os

def resize_single_mri(file_path, target_size=(256, 256, 256)):
    # Load the MRI data
    mri_data = nib.load(file_path).get_fdata()
    
    # Get the shape of the original MRI data
    original_size = mri_data.shape
    
    # Create an array of zeros with the target size
    padded_mri_data = np.zeros(target_size)
    
    # Calculate the starting indices to copy the original MRI data into the padded array
    start_indices = tuple((np.array(target_size) - np.array(original_size)) // 2)
    
    # Calculate the ending indices to copy the original MRI data into the padded array
    end_indices = tuple(start_indices + np.array(original_size))
    
    # Copy the original MRI data into the center of the padded array
    padded_mri_data[start_indices[0]:end_indices[0], 
                    start_indices[1]:end_indices[1], 
                    start_indices[2]:end_indices[2]] = mri_data
    
    return padded_mri_data

def plot_slices(original_volume, resized_volume, slice_index, title):
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    
    axes[0].imshow(original_volume[slice_index-100,:, :], cmap='gray')
    axes[0].set_title('Original ' + title)
    axes[0].axis('off')
    
    axes[1].imshow(resized_volume[:, slice_index, :], cmap='gray')
    axes[1].set_title('Resized ' + title)
    axes[1].axis('off')
    
    plt.show()

# Define the path to the MRI file
file_path = "archive/BraTS2021_Training_Data/test/BraTS2021_01559/BraTS2021_01559_t1ce.nii.gz"

# Define the target size
target_size = (256, 256, 256)

# Resize the single MRI image
resized_mri_data = resize_single_mri(file_path, target_size)

# Calculate the middle slice index for the second axis
middle_slice_index = target_size[1] // 2

# Plot the middle slice of the original and resized volume
plot_slices(original_volume, resized_mri_data, middle_slice_index, 'Middle Slice')
